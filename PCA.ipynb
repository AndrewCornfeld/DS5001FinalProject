# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# %%
import plotly_express as px
import seaborn as sns

# %%
sns.set(style='ticks')

# %%
OHCO = ['season', 'episode', 'scene', 'line', 'sentence', 'token']

# %%
colors = "YlGnBu"

# %%
L2 = pd.read_csv("office-L2.csv")
